# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
class least_mean_regressor:
    def __init__(self):
        self.theta0 = 1
        self.theta1 = 1
    
    def adaptation_0(self, trainX, trainY):
        sum=0
        for i in range(trainX.shape[0]):
            sum+=(trainY[i]-self.hyphotesis(trainX[i]))
        return sum

    def derivative(self, trainX, trainY):
        sum = 0
        for i in range(trainX.shape[0]):
            sum+=trainX[i]*(trainY[i]-self.hyphotesis(trainX[i]))
        return sum

    def hyphotesis(self, x1):
        return self.theta0 + x1*self.theta1
    
    def train(self, trainX, trainY):
        epochs = 1000
        minimum = 0.0001
        for i in range(epochs):
            theta0 = self.theta0
            theta1 = self.theta1
            delta = self.adaptation_0(train_X, train_Y)
            self.theta0 = theta0  + self.alpha*delta
            self.theta1 = theta1  + self.alpha*(self.derivative(trainX, trainY))
            if delta < minimum:
                print(i)
                break
    
    def predict(self, data):
        result = []
        print(data.shape[0])
        for i in range(data.shape[0]):
            result.append(self.hyphotesis(data[i]))
        return result

# %%
houses = datasets.load_boston()
trainX = houses['data']
trainY = houses['target']

regr = linear_model.LinearRegression()

regr.fit(trainX, trainY)
iterations = 19
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
diabetes = datasets.load_diabetes()
size_test = 40
diabetes_X = diabetes.data[:, np.newaxis, 2]
diabetes_X_train = diabetes_X[:-size_test]
diabetes_X_test = diabetes_X[-size_test:]
diabetes_y_train = diabetes.target[:-size_test]
diabetes_y_test = diabetes.target[-size_test:]

regr = linear_model.LinearRegression()

regr.fit(diabetes_X_train, diabetes_y_train)

diabetes_y_pred = regr.predict(diabetes_X_test)

print('Coefficients: \n', regr.coef_)
print("Mean squared error: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
print('Variance: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))
print('Number of Iterations:{}'.format(iterations))

plt.figure(figsize=(50,25))
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.grid()
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=2)
plt.show()
# Out:
# Coefficients:
#  [955.44001079]
# Mean squared error: 3309.16
# Variance: 0.42
